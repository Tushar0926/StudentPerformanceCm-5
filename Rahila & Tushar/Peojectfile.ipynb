# %% [markdown]
# #    CORE MODULE-5 FINAL PROJECT

# %% [markdown]
# ![Screenshot%202023-11-17%20144559.png](attachment:Screenshot%202023-11-17%20144559.png)

# %% [markdown]
# ## Import The Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## Read Dataset

# %%
data = pd.read_csv("StudentsPerformance.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
# !pip install missingno

# %%
import missingno as msno

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# ## Comparison Of Male & Female in bar chart

# %%
plt.subplots(figsize=(10,8))
data['gender'].value_counts(normalize=True)
data['gender'].value_counts(dropna=True).plot.bar(color="blue")
plt.title('Comparison Of Male and Female')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# ## Visualization the different Groups in the Dataset

# %%
plt.subplots(figsize=(15,5))
data['race/ethnicity'].value_counts(normalize=True)
data['race/ethnicity'].value_counts(dropna=False).plot.bar(color=['orange', 'green', 'blue', 'black', 'skyblue'])
plt.title('Comparison Of various Groups')
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # prepare Data

# %%
df = data.groupby('race/ethnicity').size()

# make plot
df.plot(kind='pie', subplots=True, figsize=(15,8))
plt.title('Pie Chart of Race/Ethnicity Distribution')
plt.ylabel('') 
plt.show()

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# # visualizing the Different parental education levels

# %%
plt.subplots(figsize=(15,5))
data['parental level of education'].value_counts(normalize=True)
data['parental level of education'].value_counts(dropna=False).plot.bar(color= ['red', 'green', 'blue', 'black', 'skyblue'])
plt.title('Compatison Of Parental Education')
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # visualizing the Different Types of lunch

# %%
plt.subplots(figsize=(15,5))
data['lunch'].value_counts(normalize=True)
data['lunch'].value_counts(dropna=False).plot.bar(color='brown')
plt.title('Comparison Of Different types of lunch')
plt.xlabel('types of lunch')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Comparison of Differebt Types of Test Praparetion Like Test Completed or Not

# %%
plt.subplots(figsize=(15,5))
data['test preparation course'].value_counts(normalize=True)
data['test preparation course'].value_counts(dropna=False).plot.bar(color=['black', 'red'])
plt.title('Comparison of differebt types of Test preparation')
plt.xlabel('Test completed or not')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # Visualizing The Maths Score

# %%
plt.figure(figsize=(15, 5))


data['math score'].value_counts(normalize=True).plot.bar(figsize=(18, 8), color='skyblue')

plt.title('Comparison of Math Scores')
plt.xlabel('Math Marks/Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Visualizing The Reading Score

# %%
plt.figure(figsize=(15, 5))


data['reading score'].value_counts(normalize=True).plot.bar(figsize=(18, 8), color='blue')

plt.title('Comparison of Reading Scores')
plt.xlabel('Reading Marks/Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Visualizing The Writing Score

# %%
plt.figure(figsize=(15, 5))


data['writing score'].value_counts(normalize=True).plot.bar(figsize=(18, 8), color='red')

plt.title('Comparison of Writing Scores')
plt.xlabel('Writing Marks/Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(16, 5))

plt.subplot(1, 3, 1)
sns.distplot(data['math score'])

plt.subplot(1, 3, 2)
sns.distplot(data['reading score'])

plt.subplot(1, 3, 3)
sns.distplot(data['writing score'])

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15740\1010310312.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['math score'])
# C:\Users\hp\AppData\Local\Temp\ipykernel_15740\1010310312.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # lets see the Mean of sample and population

# %% [markdown]
# ### Maths Score

# %%
#seed rendome values
np.random.seed(6)

#Take 100 sample values from the dataset of 1000 values
sample_math_marks = np.random.choice(a=data['math score'], size=100)

# sample mean
print('Sample mean for math Score:', sample_math_marks.mean())

#Population mean
print('Population mean for Math Score', data['math score'].mean())
# Out:
# Sample mean for math Score: 63.12
# Population mean for Math Score 66.089

# %% [markdown]
# ### Reading Score

# %%
#Take 100 sample values from the dataset of 1000 values
sample_reading_marks = np.random.choice(a=data['reading score'], size=100)


#Sample mean
print('\nSample mean for Reading Score:', sample_reading_marks.mean())

#Population mean
print('Population mean for reading Score', data['reading score'].mean())
# Out:
# Sample mean for Reading Score: 68.5
# Population mean for reading Score 69.169

# %% [markdown]
# ### Writing Score

# %%
#Take 100 sample values from the dataset of 1000 values
sample_writing_marks = np.random.choice(a=data['writing score'], size=100)

#Sample mean
print('\nSample mean for Writing Score:', sample_writing_marks.mean())

#Population mean
print('Population mean for Writing Score', data['writing score'].mean())
# Out:
# Sample mean for Writing Score: 71.46
# Population mean for Writing Score 68.054

# %% [markdown]
# # Let check the Confidence Interval for math score

# %%
# Impoer the scipy library
import scipy.stats as stats
import math

# Seed randome values
np.random.seed(10)

#Take sample size
sample_size=1000
sample = np.random.choice(a= data['math score'], size = sample_size)
sample_mean = sample.mean()
 
# Get the z-critical values
z_critical = stats.norm.ppf(q = 0.95)

#check the z-critical value
print('z-critical value', z_critical)

#Get the Population statndard deviation
pop_stdev = data['math score'].std()

#check the margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))

#defining our donfidence interval
confidance_interval = (sample_mean - margin_of_error,
                      sample_mean +margin_of_error)
#lets print the result
print('Confidence interval:', end=" ")
print(confidance_interval)
print('True mean: {}'.format(data['math score'].mean()))
# Out:
# z-critical value 1.6448536269514722
# Confidence interval: (64.82729483328328, 66.40470516671672)
# True mean: 66.089

# %% [markdown]
# # Let check the Confidance Interval for reading Score

# %%
# Impoer the scipy library
import scipy.stats as stats
import math

# Seed randome values
np.random.seed(10)

#Take sample size
sample_size=1000
sample = np.random.choice(a= data['reading score'], size = sample_size)
sample_mean = sample.mean()
 
# Get the z-critical values
z_critical = stats.norm.ppf(q = 0.95)

#check the z-critical value
print('z-critical value', z_critical)

#Get the Population statndard deviation
pop_stdev = data['reading score'].std()

#check the margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))

#defining our donfidence interval
confidance_interval = (sample_mean - margin_of_error,
                      sample_mean + margin_of_error)
#lets print the result
print('Confidence interval:', end=" ")
print(confidance_interval)
print('True mean: {}'.format(data['reading score'].mean()))
# Out:
# z-critical value 1.6448536269514722
# Confidence interval: (67.75757337011645, 69.27642662988355)
# True mean: 69.169

# %% [markdown]
# # Let check the Confidance Interval for Writing Score

# %%
#Take sample size
sample_size=1000
sample = np.random.choice(a= data['writing score'], size = sample_size)
sample_mean = sample.mean()
 
# Get the z-critical values
z_critical = stats.norm.ppf(q = 0.95)

#check the z-critical value
print('z-critical value', z_critical)

#Get the Population statndard deviation
pop_stdev = data['writing score'].std()

#check the margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))

#defining our donfidence interval
confidance_interval = (sample_mean - margin_of_error,
                      sample_mean +margin_of_error)
#lets print the result
print('Confidence interval:', end=" ")
print(confidance_interval)
print('True mean: {}'.format(data['writing score'].mean()))
# Out:
# z-critical value 1.6448536269514722
# Confidence interval: (67.59660035030862, 69.17739964969138)
# True mean: 68.054

# %% [markdown]
# # Comparison of Parental degree and test course

# %%
plt.subplots(figsize=(15,5))
sns.countplot(x = 'parental level of education', data = data, hue = 'test preparation course', palette = 'dark')
plt.show()

# %% [markdown]
# # Comparison of race/ethnicity and test preparation course

# %%
plt.subplots(figsize = (15,5))
sns.countplot(x = 'race/ethnicity', data = data, hue = 'test preparation course', palette = 'bright')
plt.show()

# %% [markdown]
# # setting a passing make for the students to pass on the whethe the students are pass or fail

# %% [markdown]
# ### In Math Score

# %%
plt.subplots(figsize=(15,8))
passmarks = 50

data['pass_math'] = np.where(data['math score']< passmarks, 'fail', 'pass' )
data['pass_math'].value_counts(dropna = False).plot.bar(color = 'red', figsize = (5, 3))

plt.title('Comparison of students passed or failed in maths')
plt.xlabel('ststus')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### In Reading Score

# %%
plt.subplots(figsize=(15,8))
passmarks = 50

data['pass_reading'] = np.where(data['reading score']< passmarks, 'fail', 'pass' )
data['pass_reading'].value_counts(dropna = False).plot.bar(color = 'black', figsize = (5, 3))

plt.title('Comparison of students passed or failed in reading')
plt.xlabel('ststus')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### In Writing Score

# %%
plt.subplots(figsize=(15,8))
passmarks = 50

data['pass_writing'] = np.where(data['writing score']< passmarks, 'fail', 'pass' )
data['pass_writing'].value_counts(dropna = False).plot.bar(color = 'blue', figsize = (5, 3))

plt.title('Comparison of students passed or failed in writing')
plt.xlabel('ststus')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # Comparison the total Score for each student

# %%
plt.subplots(figsize=(15,8))
data['total_score'] = data['math score'] + data['reading score'] + data['writing score']

data['total_score'].value_counts(normalize = True)
data['total_score'].value_counts(dropna =True).plot.bar(color = 'orange', figsize = (40, 8))

plt.title('Compatison of Total Score of all the Students')
plt.xlabel('total score scored by the students')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # Comparison Percentage for each of the students

# %% [markdown]
# ### Importing the math library to use for ceil

# %%
from math import *
data['percentage'] = data['total_score'] / 3

for i in range(0, 1000):
    data['percentage'][i] = ceil(data['percentage'][i])

data['percentage'].value_counts(normalize=True)
data['percentage'].value_counts(dropna=False).plot.bar(figsize=(16, 8), color='red')

plt.title('Comparison Of Percentage Score by all Students')
plt.xlabel('Percentage Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15740\3319910906.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['percentage'][i] = ceil(data['percentage'][i])

# %% [markdown]
# # Checking with student is Fail & Pass Overall

# %%
import seaborn as sns

data['status'] = data.apply(lambda x: 'Fail' if x['pass_math'] != 'pass' or
                          x['pass_reading'] != 'pass' or x['pass_writing'] != 'pass'
                          else 'Pass', axis=1)

# Plotting with seaborn
plt.figure(figsize=(15, 5))
sns.countplot(x='status', data=data, palette='dark')
plt.title('Overall Results')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ![Screenshot%202023-11-17%20150459.png](attachment:Screenshot%202023-11-17%20150459.png)

# %% [markdown]
# ### Submitted By:- Rahila & Tushar
